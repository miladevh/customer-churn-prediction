# %%
# import pakage
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

from imblearn.over_sampling import SMOTE

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

import warnings
warnings.filterwarnings('ignore')

# %%
Data_Frame = pd.read_csv('data/IT_customer_churn.csv')
Data_Frame
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
print(Data_Frame.columns)
print('len data frame: ', len(Data_Frame.columns))
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')
# len data frame:  20

# %%
Data_Frame.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   str
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   str
#  3   Dependents        7043 non-null   str
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   str
#  6   MultipleLines     7043 non-null   str
#  7   InternetService   7043 non-null   str
#  8   OnlineSecurity    7043 non-null   str
#  9   OnlineBackup      7043 non-null   str
#  10  DeviceProtection  7043 non-null   str
#  11  TechSupport       7043 non-null   str
#  12  StreamingTV       7043 non-null   str
#  13  StreamingMovies   7043 non-null   str
#  14  Contract          7043 non-null   str
#  15  PaperlessBilling  7043 non-null   str
#  16  PaymentMethod     7043 non-null   str
# ...

# %% [markdown]
# 1. جنسیت (gender)
# 2. سالمند بودن (SeniorCitizen)
# 3. داشتن شریک زندگی (Partner)
# 4. داشتن افراد تحت تکفل (Dependents)
# 5. مدت عضویت (tenure)
# 6. سرویس تلفن (PhoneService)
# 7. چندخطی بودن (MultipleLines)
# 8. سرویس اینترنت (InternetService)
# 9. امنیت آنلاین (OnlineSecurity)
# 10. پشتیبان‌گیری آنلاین (OnlineBackup)
# 11. حفاظت از دستگاه (DeviceProtection)
# 12. پشتیبانی فنی (TechSupport)
# 13. تلویزیون استریم (StreamingTV)
# 14. فیلم استریم (StreamingMovies)
# 15. قرارداد (Contract)
# 16. صورتحساب بدون کاغذ (PaperlessBilling)
# 17. روش پرداخت (PaymentMethod)
# 18. هزینه ماهانه (MonthlyCharges)
# 19. کل هزینه‌ها (TotalCharges)
# 20. ترک مشتری (Churn)

# %%
Data_Frame.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
Data_Frame['TotalCharges'] = pd.to_numeric(Data_Frame['TotalCharges'], errors='coerce')

# %%
Data_Frame.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
Data_Frame = Data_Frame.dropna(subset=['TotalCharges'])

# %%
Data_Frame.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
Data_Frame['Churn'].value_counts()
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %%
Data_Frame['Churn'].value_counts(normalize=True)
# Out:
# Churn
# No     0.734215
# Yes    0.265785
# Name: proportion, dtype: float64

# %% [markdown]
# # EDA

# %%
churn_counts = Data_Frame['Churn'].value_counts()

plt.bar(churn_counts.index, churn_counts.values, color=['green','red'])

plt.title("Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Count")

plt.show()

# %%
tenure_churn_no = Data_Frame[Data_Frame.Churn=='No'].tenure
tenure_churn_yes = Data_Frame[Data_Frame.Churn=='Yes'].tenure

plt.hist([tenure_churn_yes, tenure_churn_no],
         bins=30,
         rwidth=0.95,
         color=['green','red'],
         label=['Churn=Yes','Churn=No'])

plt.xlabel("tenure")
plt.ylabel("Number Of Customers")
plt.title("Tenure vs Churn")
plt.legend()

plt.show()

# %%
charges_churn_no = Data_Frame[Data_Frame.Churn=='No'].MonthlyCharges
charges_churn_yes = Data_Frame[Data_Frame.Churn=='Yes'].MonthlyCharges

plt.hist([charges_churn_yes, charges_churn_no],
         bins=30,
         rwidth=0.95,
         color=['green','red'],
         label=['Churn=Yes','Churn=No'])

plt.xlabel("Monthly Charges")
plt.ylabel("Number Of Customers")
plt.title("Monthly Charges vs Churn")
plt.legend()

plt.show()

# %%
total_churn_no = Data_Frame[Data_Frame.Churn=='No'].TotalCharges
total_churn_yes = Data_Frame[Data_Frame.Churn=='Yes'].TotalCharges

plt.hist([total_churn_yes, total_churn_no],
         bins=30,
         rwidth=0.95,
         color=['green','red'],
         label=['Churn=Yes','Churn=No'])

plt.xlabel("Total Charges")
plt.ylabel("Number Of Customers")
plt.title("Total Charges vs Churn")
plt.legend()

plt.show()

# %% [markdown]
# # Preprocessing

# %%
def print_unique_col_values(df):
    columns = df.columns
    for column in columns:
        if df[column].dtypes=='str':
            print(f'{column}: {df[column].unique()}')
            print('-------------------------------- \n')

# %%
print_unique_col_values(Data_Frame)
# Out:
# gender: <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
# --------------------------------
#
# Partner: <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# --------------------------------
#
# Dependents: <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# --------------------------------
#
# PhoneService: <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# --------------------------------
#
# MultipleLines: <StringArray>
# ['No phone service', 'No', 'Yes']
# Length: 3, dtype: str
# --------------------------------
#
# InternetService: <StringArray>
# ['DSL', 'Fiber optic', 'No']
# Length: 3, dtype: str
# --------------------------------
#
# OnlineSecurity: <StringArray>
# ['No', 'Yes', 'No internet service']
# Length: 3, dtype: str
# --------------------------------
#
# OnlineBackup: <StringArray>
# ['Yes', 'No', 'No internet service']
# Length: 3, dtype: str
# --------------------------------
#
# DeviceProtection: <StringArray>
# ...

# %%
Data_Frame.replace("No internet service","No",inplace=True)
Data_Frame.replace("No phone service","No",inplace=True)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0               No             DSL             No          Yes
# ...

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    Data_Frame[col] = Data_Frame[col].replace({'Yes': 1,'No': 0},inplace=True).astype(int)

# %%
Data_Frame['gender'] = Data_Frame['gender'].replace({'Male': 1, 'Female': 0}).astype(int)

# %%
for column in Data_Frame.columns:
    print(f'{column}: {Data_Frame[column].unique()}')
    print('-------------------------------- \n')
# Out:
# gender: [0 1]
# --------------------------------
#
# SeniorCitizen: [0 1]
# --------------------------------
#
# Partner: [1 0]
# --------------------------------
#
# Dependents: [0 1]
# --------------------------------
#
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# --------------------------------
#
# PhoneService: [0 1]
# --------------------------------
#
# MultipleLines: [0 1]
# --------------------------------
#
# InternetService: <StringArray>
# ['DSL', 'Fiber optic', 'No']
# Length: 3, dtype: str
# --------------------------------
#
# OnlineSecurity: [0 1]
# --------------------------------
#
# OnlineBackup: [1 0]
# --------------------------------
#
# DeviceProtection: [0 1]
# --------------------------------
#
# TechSupport: [0 1]
# --------------------------------
#
# ...

# %%
Data_Frame.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   int64
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   int64
#  3   Dependents        7032 non-null   int64
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   int64
#  6   MultipleLines     7032 non-null   int64
#  7   InternetService   7032 non-null   str
#  8   OnlineSecurity    7032 non-null   int64
#  9   OnlineBackup      7032 non-null   int64
#  10  DeviceProtection  7032 non-null   int64
#  11  TechSupport       7032 non-null   int64
#  12  StreamingTV       7032 non-null   int64
#  13  StreamingMovies   7032 non-null   int64
#  14  Contract          7032 non-null   str
#  15  PaperlessBilling  7032 non-null   int64
#  16  PaymentMethod     7032 non-null   str
# ...

# %%
Data_Frame = pd.get_dummies(Data_Frame, columns=[
    'Contract',
    'InternetService',
    'PaymentMethod'
])

# %%
bool_cols = Data_Frame.select_dtypes(include='bool').columns

Data_Frame[bool_cols] = Data_Frame[bool_cols].astype(int)

# %%
for column in Data_Frame.columns:
    print(f'{column}: {Data_Frame[column].unique()}')
    print('-------------------------------- \n')
# Out:
# gender: [0 1]
# --------------------------------
#
# SeniorCitizen: [0 1]
# --------------------------------
#
# Partner: [1 0]
# --------------------------------
#
# Dependents: [0 1]
# --------------------------------
#
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# --------------------------------
#
# PhoneService: [0 1]
# --------------------------------
#
# MultipleLines: [0 1]
# --------------------------------
#
# OnlineSecurity: [0 1]
# --------------------------------
#
# OnlineBackup: [1 0]
# --------------------------------
#
# DeviceProtection: [0 1]
# --------------------------------
#
# TechSupport: [0 1]
# --------------------------------
#
# StreamingTV: [0 1]
# --------------------------------
#
# StreamingMovies: [0 1]
# --------------------------------
#
# ...

# %% [markdown]
# # Train Model

# %%
X = Data_Frame.drop('Churn', axis=1)
y = Data_Frame['Churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %%
cols_to_scale = ['tenure', 'MonthlyCharges', 'TotalCharges']
scaler = StandardScaler()

X_train[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
X_test[cols_to_scale] = scaler.transform(X_test[cols_to_scale])

# %% [markdown]
# # Imbalanced dataset

# %%
smote = SMOTE(random_state=42)

X_train_sm, y_train_sm = smote.fit_resample(X_train, y_train)

# %%
y_train_sm.value_counts()
# Out:
# Churn
# 1    3614
# 0    3614
# Name: count, dtype: int64

# %%
lg_model = LogisticRegression()

lg_model.fit(X_train_sm, y_train_sm)
# Out:
# LogisticRegression()

# %%
y_pred = lg_model.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.77      0.82      1549
#            1       0.53      0.71      0.61       561
#
#     accuracy                           0.76      2110
#    macro avg       0.71      0.74      0.72      2110
# weighted avg       0.79      0.76      0.77      2110

# %% [markdown]
# # Random Forest

# %%
rf_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1549
#            1       0.61      0.48      0.54       561
#
#     accuracy                           0.78      2110
#    macro avg       0.72      0.68      0.70      2110
# weighted avg       0.77      0.78      0.77      2110

# %% [markdown]
# # XGBOOST

# %%
xgb_model = XGBClassifier(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    scale_pos_weight= (len(y_train) - sum(y_train)) / sum(y_train)
)

xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82      1549
#            1       0.53      0.76      0.63       561
#
#     accuracy                           0.76      2110
#    macro avg       0.71      0.76      0.72      2110
# weighted avg       0.80      0.76      0.77      2110

# %% [markdown]
# # SHAP

# %%
import shap

# %%
explainer_xgb = shap.TreeExplainer(xgb_model)

# %%
shap_values_xgb = explainer_xgb.shap_values(X_test.astype(float))
type(shap_values_xgb)
# Out:
# numpy.ndarray

# %%
shap.summary_plot(
    shap_values_xgb,
    X_test.astype(float)
)

# %%
shap.summary_plot(
    shap_values_xgb,
    X_test.astype(float),
    plot_type="bar"
)
